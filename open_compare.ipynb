# %% [markdown]
# # Get the image and the corresponding label. Compare them qform

# %%
import nrrd as nr
import nibabel as nib
import os
import numpy as np

# %%
PATH_sct_large = "../sct-testing-large/"
PATH_label = "deleener_data/"

def get_sct_path(file):
    return f"{PATH_sct_large}{file}/anat/{file}_T2w.nii.gz"

# %%
#Correspondence between reference and label data based on `spinal_segments_prediction - data - phase 1.csv'.
#unf
Center1 = {
    "sct_004": "01",
    "sct_005": "02",
    "sct_006": "03",
    "sct_007": "04",
    "sct_008": "05",
    "sct_009": "06",
    "sct_011": "07",
    "sct_012": "08",
    "sct_013": "09",
    "sct_014": "10",
    "sct_015": "11",
    "sct_016": "12",
    "sct_017": "13",
    "sct_018": "14",
    "sct_019": "15",
    "sct_022": "16",
    "sct_024": "17"}
#paris
Center2 = {
    "05": "01",
    "15": "02",
    "16": "03",
    "39": "04",
    "41": "05",
    "42": "06",
    "45": "07",
    "47": "08",
    "61": "09",
    "62": "10",
    "63": "11",
    "66": "12",
    "67": "13",
    "68": "14",
    "69": "15",
    "80": "16",
    "82": "17",
    "83": "18",
    "84": "19",
    "87": "20",
    "112": "21",
    "115": "22",
    "116": "23",
    "117": "24",
}

# %%
def get_header(file):
    """
    Return header and qform matrix the file
    Accept .nii.gz and .nrrd extention
    """
    ext = os.path.splitext(file)[1]
    if ext == ".nrrd":
        header = nr.read_header(file)
        #TODO convert to nifti ?
        matrix = header["space directions"]
    elif ext == ".gz":
        header = nib.load(file).header
        #TODO verify if this is the good way to get qform ?
        x = header["srow_x"]
        y = header["srow_y"]
        z = header["srow_z"]
        matrix = np.vstack((x, y, z))
    else:
        raise Exception(f"File extention of {file} not supported")
    return header, matrix

# %%
## Center1 unf
for sub in Center1:
    reference = sub.split("_")[1]
    label = Center1[sub]
    try:
        nii_header, nii_matrix = get_header(get_sct_path(f"sub-unfSCT{reference}"))
        nrrd_header, nrrd_matrix = get_header(f"{PATH_label}center1_Cadotte/{label}_t2-label.nrrd")
        print(f"Ref:sub-unfSCT{reference}")
        print(nii_header)
        print(f"Label:{label}_t2-label.nrrd")
        print(nrrd_header)
    except FileNotFoundError as f:
        print(f"Error on file {f}")
    print("######")
# Out:
# Ref:sub-unfSCT004
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b'?TR:1500.000 TE:11'
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 320 320  64   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.000000e+00  8.000000e-01  8.000000e-01  8.000000e-01  1.500000e+00
#   1.000000e+00  1.000000e+00  5.511571e+04]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 255
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.446931
# quatern_c       : -0.5628768
# quatern_d       : -0.43235058
# qoffset_x       : -13.209519
# qoffset_y       : 89.81659
# qoffset_z       : -273.07306
# srow_x          : [-6.0117296e-03 -2.5833905e-02  7.9956019e-01 -1.3209519e+01]
# srow_y          : [-0.77918077  0.18132104  0.         89.81659   ]
# srow_z          : [ 1.8122135e-01  7.7875239e-01  2.6524169e-02 -2.7307306e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:01_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 8.00000012e-01,  3.63901229e-08,  4.17830259e-09],
#        [ 3.63901236e-08, -7.79180780e-01, -1.81321073e-01],
#        [ 4.17830267e-09, -1.81321073e-01,  7.79180780e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -21.58555412,  143.32038879, -188.45478821]))])
# ######
# Ref:sub-unfSCT005
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b'?TR:1500.000 TE:10'
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 320 320  64   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.000000e+00  8.000000e-01  8.000000e-01  8.000000e-01  1.500000e+00
#   1.000000e+00  1.000000e+00  5.889697e+04]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 255
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.446931
# quatern_c       : -0.5628768
# quatern_d       : -0.43235058
# qoffset_x       : -13.209519
# qoffset_y       : 81.14189
# qoffset_z       : -183.43454
# srow_x          : [-6.0117296e-03 -2.5833905e-02  7.9956019e-01 -1.3209519e+01]
# srow_y          : [-0.77918077  0.18132104  0.         81.14189   ]
# srow_z          : [ 1.8122135e-01  7.7875239e-01  2.6524169e-02 -1.8343454e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:02_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 7.99560218e-01, -1.10685630e-07, -2.65231477e-02],
#        [-6.01161379e-03, -7.79180784e-01, -1.81221370e-01],
#        [ 2.58328818e-02, -1.81321052e-01,  7.78752436e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -35.24502945,  158.74208069, -213.59242249]))])
# ######
# Ref:sub-unfSCT006
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 48
# dim             : [  3 320 320  64   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.00000e+00  8.00000e-01  8.00000e-01  8.00000e-01  1.50000e+00
#   1.00000e+00  1.00000e+00  4.99107e+04]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 63
# slice_code      : sequential increasing
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 255
# glmin           : 0
# descrip         : b'TE=100;sec=49910.6975;phaseDir=+'
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.4840479
# quatern_c       : -0.51545864
# quatern_d       : -0.4840479
# qoffset_x       : -22.294432
# qoffset_y       : 134.28831
# qoffset_z       : -270.55518
# srow_x          : [  0.         0.         0.8      -22.294432]
# srow_y          : [-7.9842138e-01  5.0232418e-02  0.0000000e+00  1.3428831e+02]
# srow_z          : [ 5.0232418e-02  7.9842138e-01  0.0000000e+00 -2.7055518e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:03_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 7.99560218e-01, -1.10685630e-07, -2.65231477e-02],
#        [-6.01161379e-03, -7.79180784e-01, -1.81221370e-01],
#        [ 2.58328818e-02, -1.81321052e-01,  7.78752436e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -35.24502945,  167.41677856, -123.95389557]))])
# ######
# Ref:sub-unfSCT007
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 57
# dim             : [  3  64 320 320   1   0   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.         0.80000114 0.8        0.8        1.5        0.
#  0.         0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=1.2e+02;Time=140852.710;phase=1'
# aux_file        : b'Isocenter_at_head_coil_'
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.03141076
# quatern_c       : 0.0
# quatern_d       : 0.0
# qoffset_x       : -21.330645
# qoffset_y       : -126.19125
# qoffset_z       : -172.60335
# srow_x          : [  0.80000114   0.           0.         -21.330645  ]
# srow_y          : [ 0.0000000e+00  7.9842138e-01  5.0232418e-02 -1.2619125e+02]
# srow_z          : [ 0.0000000e+00 -5.0232418e-02  7.9842138e-01 -1.7260335e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:04_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 8.00000012e-01,  4.24646629e-08,  1.33450684e-09],
#        [ 4.24646634e-08, -7.98421392e-01, -5.02324557e-02],
#        [ 1.33450685e-09, -5.02324557e-02,  7.98421392e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -28.10558319,  120.40810394, -254.53102112]))])
# ######
# Ref:sub-unfSCT008
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 57
# dim             : [  3  64 320 320   1   0   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.        0.7999991 0.8       0.8       1.5       0.        0.
#  0.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=1.2e+02;Time=151908.090;phase=1'
# aux_file        : b'Isocenter_at_head_coil_'
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -2.4474541e-12
# quatern_c       : 0.027921615
# quatern_d       : 6.8195077e-14
# qoffset_x       : -29.369576
# qoffset_y       : -114.669876
# qoffset_z       : -146.79977
# srow_x          : [ 7.9875171e-01 -2.1839999e-13  4.4657163e-02 -2.9369576e+01]
# srow_y          : [-2.69402270e-16  8.00000012e-01  3.91760019e-12 -1.14669876e+02]
# srow_z          : [-4.4657111e-02 -3.9111999e-12  7.9875261e-01 -1.4679977e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:05_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 8.00000012e-01,  4.24646629e-08,  1.33450684e-09],
#        [ 4.24646634e-08, -7.98421392e-01, -5.02324557e-02],
#        [ 1.33450685e-09, -5.02324557e-02,  7.98421392e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -29.06943893,  126.19123077, -172.60333252]))])
# ######
# Error on file No such file or no access: '../sct-testing-large/sub-unfSCT009/anat/sub-unfSCT009_T2w.nii.gz'
# ######
# Ref:sub-unfSCT011
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 57
# dim             : [  3  64 320 320   1   0   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.        0.8000005 0.8       0.8       1.5       0.        0.
#  0.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=1.2e+02;Time=152506.715;phase=1'
# aux_file        : b'Isocenter_at_head_coil_'
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -2.4478802e-12
# quatern_c       : 0.022687353
# quatern_d       : 5.547797e-14
# qoffset_x       : -33.83583
# qoffset_y       : -116.59758
# qoffset_z       : -177.97409
# srow_x          : [ 7.9917693e-01 -1.7760000e-13  3.6290422e-02 -3.3835831e+01]
# srow_y          : [-1.1557602e-16  8.0000001e-01  3.9176002e-12 -1.1659758e+02]
# srow_z          : [-3.6290444e-02 -3.9135999e-12  7.9917645e-01 -1.7797409e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:07_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 7.99355584e-01,  2.10272142e-08, -3.21040496e-02],
#        [ 2.01996624e-08, -8.00000012e-01, -2.10272120e-08],
#        [ 3.21040496e-02, -2.01996610e-08,  7.99355584e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -25.12085915,  118.34809113, -135.67576599]))])
# ######
# Ref:sub-unfSCT012
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 57
# dim             : [  3  64 320 320   1   0   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.         0.80000067 0.8        0.8        1.5        0.
#  0.         0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=1.2e+02;Time=144401.228;phase=1'
# aux_file        : b'Isocenter_at_head_coil_'
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -2.4483254e-12
# quatern_c       : 0.007853896
# quatern_d       : 1.9273249e-14
# qoffset_x       : -30.086466
# qoffset_y       : -111.778305
# qoffset_z       : -138.35474
# srow_x          : [ 7.9990196e-01 -6.1599997e-14  1.2565847e-02 -3.0086466e+01]
# srow_y          : [ 7.00124148e-17  8.00000012e-01  3.91760019e-12 -1.11778305e+02]
# srow_z          : [-1.2565857e-02 -3.9168000e-12  7.9990131e-01 -1.3835474e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:08_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 0.80000001,  0.        ,  0.        ],
#        [ 0.        , -0.80000001,  0.        ],
#        [ 0.        ,  0.        ,  0.80000001]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -28.09156799,  120.45301056, -149.3686676 ]))])
# ######
# Ref:sub-unfSCT013
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 57
# dim             : [  3  64 320 320   1   0   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.         0.80000114 0.8        0.8        1.5        0.
#  0.         0.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=1.2e+02;Time=160322.987;phase=1'
# aux_file        : b'Isocenter_at_head_coil_'
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -2.4485002e-12
# quatern_c       : 0.0
# quatern_d       : 0.0
# qoffset_x       : -19.416937
# qoffset_y       : -103.10361
# qoffset_z       : -145.51324
# srow_x          : [  0.80000114   0.           0.         -19.416937  ]
# srow_y          : [ 0.0000000e+00  8.0000001e-01  3.9176002e-12 -1.0310361e+02]
# srow_z          : [ 0.0000000e+00 -3.9176002e-12  8.0000001e-01 -1.4551324e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:09_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 7.99176525e-01,  1.78922373e-08,  3.62891373e-02],
#        [ 1.87231262e-08, -8.00000012e-01, -1.78922370e-08],
#        [-3.62891373e-02, -1.87231264e-08,  7.99176525e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -16.51232338,  116.59758759, -180.26039124]))])
# ######
# Ref:sub-unfSCT014
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 57
# dim             : [  3  64 320 320   1   0   0   0]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.        0.8000004 0.8       0.8       1.5       0.        0.
#  0.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=1.2e+02;Time=110001.045;phase=1'
# aux_file        : b'imgComments'
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -2.4482096e-12
# quatern_c       : -0.013089588
# quatern_d       : -3.1958814e-14
# qoffset_x       : -19.45205
# qoffset_y       : -115.151794
# qoffset_z       : -122.99681
# srow_x          : [ 7.9972631e-01  1.0240000e-13 -2.0941548e-02 -1.9452049e+01]
# srow_y          : [ 1.43971289e-16  8.00000012e-01  3.91760019e-12 -1.15151794e+02]
# srow_z          : [ 2.0941559e-02 -3.9160003e-12  7.9972589e-01 -1.2299681e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:10_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 7.99176525e-01,  1.78922373e-08,  3.62891373e-02],
#        [ 1.87231262e-08, -8.00000012e-01, -1.78922370e-08],
#        [-3.62891373e-02, -1.87231264e-08,  7.99176525e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -16.51232338,  116.59758759, -180.26039124]))])
# ######
# Ref:sub-unfSCT015
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 48
# dim             : [  3 320 320  64   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.000000e+00  8.000000e-01  8.000000e-01  8.000000e-01  1.500000e+00
#   1.000000e+00  1.000000e+00  6.224212e+04]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 63
# slice_code      : alternating increasing 2
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 255
# glmin           : 0
# descrip         : b'TE=120;sec=62242.1200;phaseDir=+'
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.49781358
# quatern_c       : -0.49781358
# quatern_d       : -0.5021769
# qoffset_x       : -29.92351
# qoffset_y       : 148.48193
# qoffset_z       : -105.28851
# srow_x          : [ 0.0000000e+00  6.9812052e-03  7.9996955e-01 -2.9923510e+01]
# srow_y          : [ -0.8       0.        0.      148.48193]
# srow_z          : [ 0.0000000e+00  7.9996955e-01 -6.9812052e-03 -1.0528851e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:11_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 0.80000001,  0.        ,  0.        ],
#        [ 0.        , -0.80000001,  0.        ],
#        [ 0.        ,  0.        ,  0.80000001]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -30.98313332,  103.10361481, -145.51324463]))])
# ######
# Ref:sub-unfSCT016
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 48
# dim             : [  3 320 320  64   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.0000000e+00  8.0000001e-01  8.0000001e-01  8.0000001e-01
#   1.5000000e+00  1.0000000e+00  1.0000000e+00  5.1246695e+04]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 63
# slice_code      : alternating increasing 2
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 255
# glmin           : 0
# descrip         : b'TE=120;sec=51246.6950;phaseDir=+'
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.50347847
# quatern_c       : -0.50347847
# quatern_d       : -0.49649718
# qoffset_x       : -26.619478
# qoffset_y       : 130.11185
# qoffset_z       : -117.52914
# srow_x          : [ 0.0000000e+00 -1.1169789e-02  7.9992205e-01 -2.6619478e+01]
# srow_y          : [ -0.8       0.        0.      130.11185]
# srow_z          : [ 0.0000000e+00  7.9992205e-01  1.1169789e-02 -1.1752914e+02]
# intent_name     : b''
# magic           : b'n+1'
# Label:12_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 7.99922002e-01,  1.36249831e-08,  1.11718077e-02],
#        [ 1.38166003e-08, -8.00000012e-01, -1.36249829e-08],
#        [-1.11718077e-02, -1.38166005e-08,  7.99922002e-01]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -17.6384201 ,  109.85060883, -276.93704224]))])
# ######
# Ref:sub-unfSCT017
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 384 185  52   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.0000000e+00  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   1.5000000e+00  1.0000000e+00  1.0000000e+00  5.8077156e+04]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : aligned
# sform_code      : scanner
# quatern_b       : 0.5
# quatern_c       : -0.5
# quatern_d       : -0.5
# qoffset_x       : -32.219284
# qoffset_y       : 211.7866
# qoffset_z       : -139.32167
# srow_x          : [  0.         0.         1.       -32.219284]
# srow_y          : [ -1.       0.       0.     211.7866]
# srow_z          : [   0.         1.        -0.      -139.32167]
# intent_name     : b''
# magic           : b'n+1'
# Label:13_t2-label.nrrd
# OrderedDict([('type', 'short'), ('dimension', 3), ('space', 'left-posterior-superior'), ('sizes', array([ 64, 320, 320])), ('space directions', array([[ 0.80000001,  0.        ,  0.        ],
#        [ 0.        , -0.80000001,  0.        ],
#        [ 0.        ,  0.        ,  0.80000001]])), ('kinds', ['domain', 'domain', 'domain']), ('endian', 'little'), ('encoding', 'gzip'), ('space origin', array([ -21.3445797 ,  120.45301056, -269.85061646]))])
# ######
# Error on file No such file or no access: '../sct-testing-large/sub-unfSCT018/anat/sub-unfSCT018_T2w.nii.gz'
# ######
# Error on file No such file or no access: '../sct-testing-large/sub-unfSCT019/anat/sub-unfSCT019_T2w.nii.gz'
# ######
# Error on file No such file or no access: '../sct-testing-large/sub-unfSCT022/anat/sub-unfSCT022_T2w.nii.gz'
# ######
# Error on file No such file or no access: '../sct-testing-large/sub-unfSCT024/anat/sub-unfSCT024_T2w.nii.gz'
# ######
